# %% [markdown]
# ### Extracción de las zonas

# %%
import subprocess
import pandas as pd
import time
import os

# %%
# -*- Get all the zones -*-
try:
    os.remove('.//github_folder//spa_housing_crawler//additional_csv//zones.csv')
except Exception as e:
    print(e)

command_zone = 'scrapy crawl getZones -o ./github_folder/spa_housing_crawler/additional_csv/zones.csv'
subprocess.run(command_zone, shell=True)
# Out:
# [WinError 3] El sistema no puede encontrar la ruta especificada: './/github_folder//spa_housing_crawler//additional_csv//zones.csv'
# CompletedProcess(args='scrapy crawl getZones -o ./github_folder/spa_housing_crawler/additional_csv/zones.csv', returncode=2)

# %%
# -*- Load zone dataframe -*-
all_zones = pd.read_csv(r"C:\Users\hecto\github_folder\spa_housing_crawler\additional_csv\zones.csv")

# %%
# -*- Get all the links -*-
for zone in all_zones.iloc[:].itertuples():
    print("\n***********************")
    print(f"Extracting {zone.type} houses links from {zone.zone}")
    print("***********************\n\n")
    time.sleep(3)

    command_links = f'scrapy crawl getLinks -a start={zone.zone} -o ./additional_csv/links.csv'
    subprocess.run(command_links, shell=True)
    print("********   PROVINCE LINK EXTRACTION FINISHED!   Waiting 45 seconds before starting with new province")
    time.sleep(45)
# Out:
# ***********************
# Extracting selling houses links from http://idealista.com/venta-viviendas/a-coruna-provincia/mapa
# ***********************
#
#
# ********   PROVINCE LINK EXTRACTION FINISHED!   Waiting 45 seconds before starting with new province
#
# ***********************
# Extracting selling houses links from http://idealista.com/venta-viviendas/alava/mapa
# ***********************
#
#
# ********   PROVINCE LINK EXTRACTION FINISHED!   Waiting 45 seconds before starting with new province
#
# ***********************
# Extracting selling houses links from http://idealista.com/venta-viviendas/albacete-provincia/mapa
# ***********************
#
#
# ********   PROVINCE LINK EXTRACTION FINISHED!   Waiting 45 seconds before starting with new province
#
# ***********************
# Extracting selling houses links from http://idealista.com/venta-viviendas/alicante/mapa
# ***********************
#
#
# ********   PROVINCE LINK EXTRACTION FINISHED!   Waiting 45 seconds before starting with new province
#
# ***********************
# Extracting selling houses links from http://idealista.com/venta-viviendas/almeria-provincia/mapa
# ***********************
#
#
# ********   PROVINCE LINK EXTRACTION FINISHED!   Waiting 45 seconds before starting with new province
#
# ***********************
# Extracting selling houses links from http://idealista.com/venta-viviendas/andorra-provincia/mapa
# ***********************
#
#
# ********   PROVINCE LINK EXTRACTION FINISHED!   Waiting 45 seconds before starting with new province
#
# ***********************
# Extracting selling houses links from http://idealista.com/venta-viviendas/asturias/mapa
# ***********************
#
#
# ********   PROVINCE LINK EXTRACTION FINISHED!   Waiting 45 seconds before starting with new province
#
# ***********************
# Extracting selling houses links from http://idealista.com/venta-viviendas/avila-provincia/mapa
# ***********************
#
#
# ********   PROVINCE LINK EXTRACTION FINISHED!   Waiting 45 seconds before starting with new province
#
# ***********************
# Extracting selling houses links from http://idealista.com/venta-viviendas/badajoz-provincia/mapa
# ***********************
#
#
# ********   PROVINCE LINK EXTRACTION FINISHED!   Waiting 45 seconds before starting with new province
#
# ***********************
# Extracting selling houses links from http://idealista.com/venta-viviendas/balears-illes/mapa
# ***********************
#
#
# ********   PROVINCE LINK EXTRACTION FINISHED!   Waiting 45 seconds before starting with new province
#
# ***********************
# Extracting selling houses links from http://idealista.com/venta-viviendas/barcelona-provincia/mapa
# ***********************
#
#
# ********   PROVINCE LINK EXTRACTION FINISHED!   Waiting 45 seconds before starting with new province
#
# ***********************
# Extracting selling houses links from http://idealista.com/venta-viviendas/burgos-provincia/mapa
# ***********************
#
#
# ********   PROVINCE LINK EXTRACTION FINISHED!   Waiting 45 seconds before starting with new province
#
# ***********************
# Extracting selling houses links from http://idealista.com/venta-viviendas/caceres-provincia/mapa
# ***********************
#
#
# ********   PROVINCE LINK EXTRACTION FINISHED!   Waiting 45 seconds before starting with new province
#
# ***********************
# Extracting selling houses links from http://idealista.com/venta-viviendas/cadiz-provincia/mapa
# ***********************
#
#
# ********   PROVINCE LINK EXTRACTION FINISHED!   Waiting 45 seconds before starting with new province
#
# ***********************
# Extracting selling houses links from http://idealista.com/venta-viviendas/cantabria/mapa
# ***********************
#
#
# ********   PROVINCE LINK EXTRACTION FINISHED!   Waiting 45 seconds before starting with new province
#
# ***********************
# Extracting selling houses links from http://idealista.com/venta-viviendas/castellon/mapa
# ***********************
#
#
# ********   PROVINCE LINK EXTRACTION FINISHED!   Waiting 45 seconds before starting with new province
#
# ***********************
# Extracting selling houses links from http://idealista.com/venta-viviendas/cerdanya-francesa/mapa
# ***********************
#
#
# ********   PROVINCE LINK EXTRACTION FINISHED!   Waiting 45 seconds before starting with new province
#
# ***********************
# Extracting selling houses links from http://idealista.com/venta-viviendas/ceuta-provincia/mapa
# ***********************
#
#
# ********   PROVINCE LINK EXTRACTION FINISHED!   Waiting 45 seconds before starting with new province
#
# ***********************
# Extracting selling houses links from http://idealista.com/venta-viviendas/ciudad-real-provincia/mapa
# ***********************
#
#
# ********   PROVINCE LINK EXTRACTION FINISHED!   Waiting 45 seconds before starting with new province
#
# ***********************
# Extracting selling houses links from http://idealista.com/venta-viviendas/cordoba-provincia/mapa
# ***********************
#
#
# ********   PROVINCE LINK EXTRACTION FINISHED!   Waiting 45 seconds before starting with new province
#
# ***********************
# Extracting selling houses links from http://idealista.com/venta-viviendas/cuenca-provincia/mapa
# ***********************
#
#
# ********   PROVINCE LINK EXTRACTION FINISHED!   Waiting 45 seconds before starting with new province
#
# ***********************
# Extracting selling houses links from http://idealista.com/venta-viviendas/girona-provincia/mapa
# ***********************
#
#
# ********   PROVINCE LINK EXTRACTION FINISHED!   Waiting 45 seconds before starting with new province
#
# ***********************
# Extracting selling houses links from http://idealista.com/venta-viviendas/granada-provincia/mapa
# ***********************
#
#
# ********   PROVINCE LINK EXTRACTION FINISHED!   Waiting 45 seconds before starting with new province
#
# ***********************
# Extracting selling houses links from http://idealista.com/venta-viviendas/guadalajara-provincia/mapa
# ***********************
#
#
# ********   PROVINCE LINK EXTRACTION FINISHED!   Waiting 45 seconds before starting with new province
#
# ***********************
# Extracting selling houses links from http://idealista.com/venta-viviendas/guipuzcoa/mapa
# ***********************
#
#
# ********   PROVINCE LINK EXTRACTION FINISHED!   Waiting 45 seconds before starting with new province
#
# ***********************
# Extracting selling houses links from http://idealista.com/venta-viviendas/huelva-provincia/mapa
# ***********************
#
#
# ********   PROVINCE LINK EXTRACTION FINISHED!   Waiting 45 seconds before starting with new province
#
# ***********************
# Extracting selling houses links from http://idealista.com/venta-viviendas/huesca-provincia/mapa
# ***********************
#
#
# ********   PROVINCE LINK EXTRACTION FINISHED!   Waiting 45 seconds before starting with new province
#
# ***********************
# Extracting selling houses links from http://idealista.com/venta-viviendas/jaen-provincia/mapa
# ***********************
#
#
# ********   PROVINCE LINK EXTRACTION FINISHED!   Waiting 45 seconds before starting with new province
#
# ***********************
# Extracting selling houses links from http://idealista.com/venta-viviendas/la-rioja/mapa
# ***********************
#
#
# ********   PROVINCE LINK EXTRACTION FINISHED!   Waiting 45 seconds before starting with new province
#
# ***********************
# Extracting selling houses links from http://idealista.com/venta-viviendas/las-palmas/mapa
# ***********************
#
#
# ********   PROVINCE LINK EXTRACTION FINISHED!   Waiting 45 seconds before starting with new province
#
# ***********************
# Extracting selling houses links from http://idealista.com/venta-viviendas/leon-provincia/mapa
# ***********************
#
#
# ********   PROVINCE LINK EXTRACTION FINISHED!   Waiting 45 seconds before starting with new province
#
# ***********************
# Extracting selling houses links from http://idealista.com/venta-viviendas/lleida-provincia/mapa
# ***********************
#
#
# ********   PROVINCE LINK EXTRACTION FINISHED!   Waiting 45 seconds before starting with new province
#
# ***********************
# Extracting selling houses links from http://idealista.com/venta-viviendas/lugo-provincia/mapa
# ***********************
#
#
# ********   PROVINCE LINK EXTRACTION FINISHED!   Waiting 45 seconds before starting with new province
#
# ***********************
# Extracting selling houses links from http://idealista.com/venta-viviendas/madrid-provincia/mapa
# ***********************
#
#
# ********   PROVINCE LINK EXTRACTION FINISHED!   Waiting 45 seconds before starting with new province
#
# ***********************
# Extracting selling houses links from http://idealista.com/venta-viviendas/malaga-provincia/mapa
# ***********************
#
#
# ********   PROVINCE LINK EXTRACTION FINISHED!   Waiting 45 seconds before starting with new province
#
# ***********************
# Extracting selling houses links from http://idealista.com/venta-viviendas/melilla-provincia/mapa
# ***********************
#
#
# ********   PROVINCE LINK EXTRACTION FINISHED!   Waiting 45 seconds before starting with new province
#
# ***********************
# Extracting selling houses links from http://idealista.com/venta-viviendas/murcia-provincia/mapa
# ***********************
#
#
# ********   PROVINCE LINK EXTRACTION FINISHED!   Waiting 45 seconds before starting with new province
#
# ***********************
# Extracting selling houses links from http://idealista.com/venta-viviendas/navarra/mapa
# ***********************
#
#
# ********   PROVINCE LINK EXTRACTION FINISHED!   Waiting 45 seconds before starting with new province
#
# ***********************
# Extracting selling houses links from http://idealista.com/venta-viviendas/ourense-provincia/mapa
# ***********************
#
#
# ********   PROVINCE LINK EXTRACTION FINISHED!   Waiting 45 seconds before starting with new province
#
# ***********************
# Extracting selling houses links from http://idealista.com/venta-viviendas/pais-vasco-frances/mapa
# ***********************
#
#
# ********   PROVINCE LINK EXTRACTION FINISHED!   Waiting 45 seconds before starting with new province
#
# ***********************
# Extracting selling houses links from http://idealista.com/venta-viviendas/palencia-provincia/mapa
# ***********************
#
#
# ********   PROVINCE LINK EXTRACTION FINISHED!   Waiting 45 seconds before starting with new province
#
# ***********************
# Extracting selling houses links from http://idealista.com/venta-viviendas/pontevedra-provincia/mapa
# ***********************
#
#
# ********   PROVINCE LINK EXTRACTION FINISHED!   Waiting 45 seconds before starting with new province
#
# ***********************
# Extracting selling houses links from http://idealista.com/venta-viviendas/salamanca-provincia/mapa
# ***********************
#
#
# ********   PROVINCE LINK EXTRACTION FINISHED!   Waiting 45 seconds before starting with new province
#
# ***********************
# Extracting selling houses links from http://idealista.com/venta-viviendas/santa-cruz-de-tenerife-provincia/mapa
# ***********************
#
#
# ********   PROVINCE LINK EXTRACTION FINISHED!   Waiting 45 seconds before starting with new province
#
# ***********************
# Extracting selling houses links from http://idealista.com/venta-viviendas/segovia-provincia/mapa
# ***********************
#
#
# ********   PROVINCE LINK EXTRACTION FINISHED!   Waiting 45 seconds before starting with new province
#
# ***********************
# Extracting selling houses links from http://idealista.com/venta-viviendas/sevilla-provincia/mapa
# ***********************
#
#
# ********   PROVINCE LINK EXTRACTION FINISHED!   Waiting 45 seconds before starting with new province
#
# ***********************
# Extracting selling houses links from http://idealista.com/venta-viviendas/soria-provincia/mapa
# ***********************
#
#
# ********   PROVINCE LINK EXTRACTION FINISHED!   Waiting 45 seconds before starting with new province
#
# ***********************
# Extracting selling houses links from http://idealista.com/venta-viviendas/tarragona-provincia/mapa
# ***********************
#
#
# ********   PROVINCE LINK EXTRACTION FINISHED!   Waiting 45 seconds before starting with new province
#
# ***********************
# Extracting selling houses links from http://idealista.com/venta-viviendas/teruel-provincia/mapa
# ***********************
#
#
# ********   PROVINCE LINK EXTRACTION FINISHED!   Waiting 45 seconds before starting with new province
#
# ***********************
# Extracting selling houses links from http://idealista.com/venta-viviendas/toledo-provincia/mapa
# ***********************
#
#
# ********   PROVINCE LINK EXTRACTION FINISHED!   Waiting 45 seconds before starting with new province
#
# ***********************
# Extracting selling houses links from http://idealista.com/venta-viviendas/valencia-provincia/mapa
# ***********************
#
#
# ********   PROVINCE LINK EXTRACTION FINISHED!   Waiting 45 seconds before starting with new province
#
# ***********************
# Extracting selling houses links from http://idealista.com/venta-viviendas/valladolid-provincia/mapa
# ***********************
#
#
# ********   PROVINCE LINK EXTRACTION FINISHED!   Waiting 45 seconds before starting with new province
#
# ***********************
# Extracting selling houses links from http://idealista.com/venta-viviendas/vizcaya/mapa
# ***********************
#
#
# ********   PROVINCE LINK EXTRACTION FINISHED!   Waiting 45 seconds before starting with new province
#
# ***********************
# Extracting selling houses links from http://idealista.com/venta-viviendas/zamora-provincia/mapa
# ***********************
#
#
# ********   PROVINCE LINK EXTRACTION FINISHED!   Waiting 45 seconds before starting with new province
#
# ***********************
# Extracting selling houses links from http://idealista.com/venta-viviendas/zaragoza-provincia/mapa
# ***********************
#
#
# ********   PROVINCE LINK EXTRACTION FINISHED!   Waiting 45 seconds before starting with new province
#
# ***********************
# Extracting renting houses links from http://idealista.com/alquiler-viviendas/a-coruna-provincia/mapa
# ***********************
#
#
# ********   PROVINCE LINK EXTRACTION FINISHED!   Waiting 45 seconds before starting with new province
#
# ***********************
# Extracting renting houses links from http://idealista.com/alquiler-viviendas/alava/mapa
# ***********************
#
#
# ********   PROVINCE LINK EXTRACTION FINISHED!   Waiting 45 seconds before starting with new province
#
# ***********************
# Extracting renting houses links from http://idealista.com/alquiler-viviendas/albacete-provincia/mapa
# ***********************
#
#
# ********   PROVINCE LINK EXTRACTION FINISHED!   Waiting 45 seconds before starting with new province
#
# ***********************
# Extracting renting houses links from http://idealista.com/alquiler-viviendas/alicante/mapa
# ***********************
#
#
# ********   PROVINCE LINK EXTRACTION FINISHED!   Waiting 45 seconds before starting with new province
#
# ***********************
# Extracting renting houses links from http://idealista.com/alquiler-viviendas/almeria-provincia/mapa
# ***********************
#
#
# ********   PROVINCE LINK EXTRACTION FINISHED!   Waiting 45 seconds before starting with new province
#
# ***********************
# Extracting renting houses links from http://idealista.com/alquiler-viviendas/andorra-provincia/mapa
# ***********************
#
#
# ********   PROVINCE LINK EXTRACTION FINISHED!   Waiting 45 seconds before starting with new province
#
# ***********************
# Extracting renting houses links from http://idealista.com/alquiler-viviendas/asturias/mapa
# ***********************
#
#
# ********   PROVINCE LINK EXTRACTION FINISHED!   Waiting 45 seconds before starting with new province
#
# ***********************
# Extracting renting houses links from http://idealista.com/alquiler-viviendas/avila-provincia/mapa
# ***********************
#
#
# ********   PROVINCE LINK EXTRACTION FINISHED!   Waiting 45 seconds before starting with new province
#
# ***********************
# Extracting renting houses links from http://idealista.com/alquiler-viviendas/badajoz-provincia/mapa
# ***********************
#
#
# ********   PROVINCE LINK EXTRACTION FINISHED!   Waiting 45 seconds before starting with new province
#
# ***********************
# Extracting renting houses links from http://idealista.com/alquiler-viviendas/balears-illes/mapa
# ***********************
#
#
# ********   PROVINCE LINK EXTRACTION FINISHED!   Waiting 45 seconds before starting with new province
#
# ***********************
# Extracting renting houses links from http://idealista.com/alquiler-viviendas/barcelona-provincia/mapa
# ***********************
#
#
# ********   PROVINCE LINK EXTRACTION FINISHED!   Waiting 45 seconds before starting with new province
#
# ***********************
# Extracting renting houses links from http://idealista.com/alquiler-viviendas/burgos-provincia/mapa
# ***********************
#
#
# ********   PROVINCE LINK EXTRACTION FINISHED!   Waiting 45 seconds before starting with new province
#
# ***********************
# Extracting renting houses links from http://idealista.com/alquiler-viviendas/caceres-provincia/mapa
# ***********************
#
#
# ********   PROVINCE LINK EXTRACTION FINISHED!   Waiting 45 seconds before starting with new province
#
# ***********************
# Extracting renting houses links from http://idealista.com/alquiler-viviendas/cadiz-provincia/mapa
# ***********************
#
#
# ********   PROVINCE LINK EXTRACTION FINISHED!   Waiting 45 seconds before starting with new province
#
# ***********************
# Extracting renting houses links from http://idealista.com/alquiler-viviendas/cantabria/mapa
# ***********************
#
#
# ********   PROVINCE LINK EXTRACTION FINISHED!   Waiting 45 seconds before starting with new province
#
# ***********************
# Extracting renting houses links from http://idealista.com/alquiler-viviendas/castellon/mapa
# ***********************
#
#
# ********   PROVINCE LINK EXTRACTION FINISHED!   Waiting 45 seconds before starting with new province
#
# ***********************
# Extracting renting houses links from http://idealista.com/alquiler-viviendas/cerdanya-francesa/mapa
# ***********************
#
#
# ********   PROVINCE LINK EXTRACTION FINISHED!   Waiting 45 seconds before starting with new province
#
# ***********************
# Extracting renting houses links from http://idealista.com/alquiler-viviendas/ceuta-provincia/mapa
# ***********************
#
#
# ********   PROVINCE LINK EXTRACTION FINISHED!   Waiting 45 seconds before starting with new province
#
# ***********************
# Extracting renting houses links from http://idealista.com/alquiler-viviendas/ciudad-real-provincia/mapa
# ***********************
#
#
# ********   PROVINCE LINK EXTRACTION FINISHED!   Waiting 45 seconds before starting with new province
#
# ***********************
# Extracting renting houses links from http://idealista.com/alquiler-viviendas/cordoba-provincia/mapa
# ***********************
#
#
# ********   PROVINCE LINK EXTRACTION FINISHED!   Waiting 45 seconds before starting with new province
#
# ***********************
# Extracting renting houses links from http://idealista.com/alquiler-viviendas/cuenca-provincia/mapa
# ***********************
#
#
# ********   PROVINCE LINK EXTRACTION FINISHED!   Waiting 45 seconds before starting with new province
#
# ***********************
# Extracting renting houses links from http://idealista.com/alquiler-viviendas/girona-provincia/mapa
# ***********************
#
#
# ********   PROVINCE LINK EXTRACTION FINISHED!   Waiting 45 seconds before starting with new province
#
# ***********************
# Extracting renting houses links from http://idealista.com/alquiler-viviendas/granada-provincia/mapa
# ***********************
#
#
# ********   PROVINCE LINK EXTRACTION FINISHED!   Waiting 45 seconds before starting with new province
#
# ***********************
# Extracting renting houses links from http://idealista.com/alquiler-viviendas/guadalajara-provincia/mapa
# ***********************
#
#
# ********   PROVINCE LINK EXTRACTION FINISHED!   Waiting 45 seconds before starting with new province
#
# ***********************
# Extracting renting houses links from http://idealista.com/alquiler-viviendas/guipuzcoa/mapa
# ***********************
#
#
# ********   PROVINCE LINK EXTRACTION FINISHED!   Waiting 45 seconds before starting with new province
#
# ***********************
# Extracting renting houses links from http://idealista.com/alquiler-viviendas/huelva-provincia/mapa
# ***********************
#
#
# ********   PROVINCE LINK EXTRACTION FINISHED!   Waiting 45 seconds before starting with new province
#
# ***********************
# Extracting renting houses links from http://idealista.com/alquiler-viviendas/huesca-provincia/mapa
# ***********************
#
#
# ********   PROVINCE LINK EXTRACTION FINISHED!   Waiting 45 seconds before starting with new province
#
# ***********************
# Extracting renting houses links from http://idealista.com/alquiler-viviendas/jaen-provincia/mapa
# ***********************
#
#
# ********   PROVINCE LINK EXTRACTION FINISHED!   Waiting 45 seconds before starting with new province
#
# ***********************
# Extracting renting houses links from http://idealista.com/alquiler-viviendas/la-rioja/mapa
# ***********************
#
#
# ********   PROVINCE LINK EXTRACTION FINISHED!   Waiting 45 seconds before starting with new province
#
# ***********************
# Extracting renting houses links from http://idealista.com/alquiler-viviendas/las-palmas/mapa
# ***********************
#
#
# ********   PROVINCE LINK EXTRACTION FINISHED!   Waiting 45 seconds before starting with new province
#
# ***********************
# Extracting renting houses links from http://idealista.com/alquiler-viviendas/leon-provincia/mapa
# ***********************
#
#
# ********   PROVINCE LINK EXTRACTION FINISHED!   Waiting 45 seconds before starting with new province
#
# ***********************
# Extracting renting houses links from http://idealista.com/alquiler-viviendas/lleida-provincia/mapa
# ***********************
#
#
# ********   PROVINCE LINK EXTRACTION FINISHED!   Waiting 45 seconds before starting with new province
#
# ***********************
# Extracting renting houses links from http://idealista.com/alquiler-viviendas/lugo-provincia/mapa
# ***********************
#
#
# ********   PROVINCE LINK EXTRACTION FINISHED!   Waiting 45 seconds before starting with new province
#
# ***********************
# Extracting renting houses links from http://idealista.com/alquiler-viviendas/madrid-provincia/mapa
# ***********************
#
#
# ********   PROVINCE LINK EXTRACTION FINISHED!   Waiting 45 seconds before starting with new province
#
# ***********************
# Extracting renting houses links from http://idealista.com/alquiler-viviendas/malaga-provincia/mapa
# ***********************
#
#
# ********   PROVINCE LINK EXTRACTION FINISHED!   Waiting 45 seconds before starting with new province
#
# ***********************
# Extracting renting houses links from http://idealista.com/alquiler-viviendas/melilla-provincia/mapa
# ***********************
#
#
# ********   PROVINCE LINK EXTRACTION FINISHED!   Waiting 45 seconds before starting with new province
#
# ***********************
# Extracting renting houses links from http://idealista.com/alquiler-viviendas/murcia-provincia/mapa
# ***********************
#
#
# ********   PROVINCE LINK EXTRACTION FINISHED!   Waiting 45 seconds before starting with new province
#
# ***********************
# Extracting renting houses links from http://idealista.com/alquiler-viviendas/navarra/mapa
# ***********************
#
#
# ********   PROVINCE LINK EXTRACTION FINISHED!   Waiting 45 seconds before starting with new province
#
# ***********************
# Extracting renting houses links from http://idealista.com/alquiler-viviendas/ourense-provincia/mapa
# ***********************
#
#
# ********   PROVINCE LINK EXTRACTION FINISHED!   Waiting 45 seconds before starting with new province
#
# ***********************
# Extracting renting houses links from http://idealista.com/alquiler-viviendas/pais-vasco-frances/mapa
# ***********************
#
#
# ********   PROVINCE LINK EXTRACTION FINISHED!   Waiting 45 seconds before starting with new province
#
# ***********************
# Extracting renting houses links from http://idealista.com/alquiler-viviendas/palencia-provincia/mapa
# ***********************
#
#
# ********   PROVINCE LINK EXTRACTION FINISHED!   Waiting 45 seconds before starting with new province
#
# ***********************
# Extracting renting houses links from http://idealista.com/alquiler-viviendas/pontevedra-provincia/mapa
# ***********************
#
#
# ********   PROVINCE LINK EXTRACTION FINISHED!   Waiting 45 seconds before starting with new province
#
# ***********************
# Extracting renting houses links from http://idealista.com/alquiler-viviendas/salamanca-provincia/mapa
# ***********************
#
#
# ********   PROVINCE LINK EXTRACTION FINISHED!   Waiting 45 seconds before starting with new province
#
# ***********************
# Extracting renting houses links from http://idealista.com/alquiler-viviendas/santa-cruz-de-tenerife-provincia/mapa
# ***********************
#
#
# ********   PROVINCE LINK EXTRACTION FINISHED!   Waiting 45 seconds before starting with new province
#
# ***********************
# Extracting renting houses links from http://idealista.com/alquiler-viviendas/segovia-provincia/mapa
# ***********************
#
#
# ********   PROVINCE LINK EXTRACTION FINISHED!   Waiting 45 seconds before starting with new province
#
# ***********************
# Extracting renting houses links from http://idealista.com/alquiler-viviendas/sevilla-provincia/mapa
# ***********************
#
#
# ********   PROVINCE LINK EXTRACTION FINISHED!   Waiting 45 seconds before starting with new province
#
# ***********************
# Extracting renting houses links from http://idealista.com/alquiler-viviendas/soria-provincia/mapa
# ***********************
#
#
# ********   PROVINCE LINK EXTRACTION FINISHED!   Waiting 45 seconds before starting with new province
#
# ***********************
# Extracting renting houses links from http://idealista.com/alquiler-viviendas/tarragona-provincia/mapa
# ***********************
#
#
# ********   PROVINCE LINK EXTRACTION FINISHED!   Waiting 45 seconds before starting with new province
#
# ***********************
# Extracting renting houses links from http://idealista.com/alquiler-viviendas/teruel-provincia/mapa
# ***********************
#
#
# ********   PROVINCE LINK EXTRACTION FINISHED!   Waiting 45 seconds before starting with new province
#
# ***********************
# Extracting renting houses links from http://idealista.com/alquiler-viviendas/toledo-provincia/mapa
# ***********************
#
#
# ********   PROVINCE LINK EXTRACTION FINISHED!   Waiting 45 seconds before starting with new province
#
# ***********************
# Extracting renting houses links from http://idealista.com/alquiler-viviendas/valencia-provincia/mapa
# ***********************
#
#
# ********   PROVINCE LINK EXTRACTION FINISHED!   Waiting 45 seconds before starting with new province
#
# ***********************
# Extracting renting houses links from http://idealista.com/alquiler-viviendas/valladolid-provincia/mapa
# ***********************
#
#
# ********   PROVINCE LINK EXTRACTION FINISHED!   Waiting 45 seconds before starting with new province
#
# ***********************
# Extracting renting houses links from http://idealista.com/alquiler-viviendas/vizcaya/mapa
# ***********************
#
#
# ********   PROVINCE LINK EXTRACTION FINISHED!   Waiting 45 seconds before starting with new province
#
# ***********************
# Extracting renting houses links from http://idealista.com/alquiler-viviendas/zamora-provincia/mapa
# ***********************
#
#
# ********   PROVINCE LINK EXTRACTION FINISHED!   Waiting 45 seconds before starting with new province
#
# ***********************
# Extracting renting houses links from http://idealista.com/alquiler-viviendas/zaragoza-provincia/mapa
# ***********************
#
#
# ********   PROVINCE LINK EXTRACTION FINISHED!   Waiting 45 seconds before starting with new province

# %%
# -*- Get all the denied links -*-
denied_flag = True
while denied_flag:
    denied_links = []
    try:
        with open('logLink.txt') as log:
            denied_links = log.readlines()
            denied_links = [s.strip() for s in denied_links]
        try:
            os.remove('logLink.txt')
        except:
            denied_flag = False

        print("\n***********************")
        print(f"Extracting denied {len(denied_links)} houses links")
        print("***********************\n\n")
        time.sleep(3)

        for link in denied_links:
            command_denied = f'scrapy crawl getLinks -a start={link} -o ./additional_csv/links.csv'
            subprocess.run(command_denied, shell=True)
        # -*- Check if still are denied links -*-
        if os.path.isfile('./logLink.txt'):
            print("********   STILL ARE DENIED LINKS! Waiting 3 minutes before restarting extraction")
            time.sleep(180)
        else:
            denied_flag = False
    except:
        denied_flag = False
